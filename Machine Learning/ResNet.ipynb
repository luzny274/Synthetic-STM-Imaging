# %%
import ctypes
ctypes.CDLL("libiomp5md.dll", mode=ctypes.RTLD_GLOBAL)
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler

import numpy as np
import copy
import time

import pytorch_utils
import dataset_utils

print("\nInitializing PyTorch...")
utils = pytorch_utils.Utils(dataset_utils.MyDataset, 0.8, 0.15, 0.05)
utils.dataset.select_target("count")

input_size  = utils.dataset.X.shape[1] * utils.dataset.X.shape[2]
output_size = utils.dataset.Y.shape[1]

print("Success!", input_size, output_size)
# Out:
# Initializing PyTorch...
# Cuda available:  True
# Using Cuda:      True
# Loading npz dataset file...
# (46799, 64, 64, 2)
# NVIDIA GeForce RTX 3060
# Success! 4096 1

# %%
from functools import reduce
from operator import __add__

class Conv2dSamePadding(nn.Conv2d):
    def __init__(self,*args,**kwargs):
        super(Conv2dSamePadding, self).__init__(*args, **kwargs)
        self.zero_pad_2d = nn.ZeroPad2d(reduce(__add__,
            [(k // 2 + (k - 2 * (k // 2)) - 1, k // 2) for k in self.kernel_size[::-1]]))

    def forward(self, input):
        return  self._conv_forward(self.zero_pad_2d(input), self.weight, self.bias)

class CNN(nn.Module):
    def __init__(self, channels_in, channels_out, kernel_size, stride, activation):
        super().__init__()

        self.conv = Conv2dSamePadding(
            in_channels=channels_in, 
            out_channels=channels_out, 
            kernel_size=kernel_size, 
            stride = stride,
            bias=False
        )

        self.bn = nn.BatchNorm2d(channels_out)

        self.activation = activation

    def forward(self, x):
        x = self.bn(self.conv(x))
        if self.activation:
            x = F.leaky_relu(x)
        return x

class ResidualBlock(nn.Module):
    def __init__(self, channels_in, channels_out, kernel_size, stride):
        super().__init__()
        
        self.cnn1 = CNN(channels_in , channels_out, kernel_size, stride, activation=True)
        self.cnn2 = CNN(channels_out, channels_out, kernel_size, 1     , activation=False)

        self.residual_scaling = nn.Parameter(torch.tensor(0.1), requires_grad=True)

        self.stride = stride
        self.downsample = None
        if self.stride > 1:
            self.downsample = CNN(channels_in , channels_out, kernel_size = 1, stride=stride, activation=False)

    def forward(self, x):
        residual = self.downsample(x) if self.stride > 1 else x
        
        x = self.cnn1(x)
        x = self.cnn2(x)
        x = x * self.residual_scaling + residual
        x = F.leaky_relu(x)

        return x

class ResNet(nn.Module):
    def __init__(self, params):
        super(ResNet, self).__init__()

        self.layers = nn.ModuleList()

        block_count = 1
        stages = 3
        filters_start = 64
        kernel_size = 3

        original_channels = 1

        self.layers.append(CNN(original_channels, filters_start, kernel_size, stride = 1, activation = True))
        prev_channels_out = filters_start
        for stage in range(stages):
            for block in range(block_count):
                channels_out = filters_start * (1 << stage)
                stride = 2 if stage > 0 and block == 0 else 1
                self.layers.append(ResidualBlock(prev_channels_out, channels_out, kernel_size, stride))
                prev_channels_out = channels_out

        self.layers.append(nn.AdaptiveAvgPool2d((1, 1)))
        #print("prev_channels_out", prev_channels_out)
        self.linear = nn.Linear(prev_channels_out, 1)

    def forward(self, x):
        x = x.view(x.shape[0], 1, x.shape[1], x.shape[2])
        x = x.to(torch.float32)
        for layer in self.layers:
            x = layer(x)

        x = x.view(x.shape[0], -1)
        x = self.linear(x)
        return x

    def get_input_weights(self):
        return torch.tensor(0)

# %%
params = {'batch_size': 16, 'loss': F.smooth_l1_loss, 'weight_decay': 0, 'epochs': 10, 'lr': 1e-5, 'batch_growth': False, 'l1_reg': 0}

min_lr = 5e-4
max_lr = 5e-2

model, train_losses, learning_rates, best_lr_ResNet = utils.Learning_Rate_Range_Test(ResNet, min_lr, max_lr, params)
print("best_lr:", best_lr_ResNet)
# Out:
# gamma per epoch: 1.5848931924611136
# residual: 7.105427357601002e-14
# Test; 	Test loss: 6.4190923 	 time: 14s
#
# Initial: Train loss: 6.4190923
#
# Step:1 	Train loss: 2.5208137 	LR: 5.00e-04	 time: 43s
# Step:2 	Train loss: 2.5135856 	LR: 7.92e-04	 time: 43s
# Step:3 	Train loss: 2.5010418 	LR: 1.26e-03	 time: 43s
# Step:4 	Train loss: 2.5472213 	LR: 1.99e-03	 time: 43s
# Step:5 	Train loss: 2.5767993 	LR: 3.15e-03	 time: 43s
# Step:6 	Train loss: 2.4574807 	LR: 5.00e-03	 time: 44s
# Step:7 	Train loss: 2.4328806 	LR: 7.92e-03	 time: 43s
# Step:8 	Train loss: 2.3485483 	LR: 1.26e-02	 time: 44s
# Step:9 	Train loss: 2.4095335 	LR: 1.99e-02	 time: 43s
# Step:10 	Train loss: 2.4830944 	LR: 3.15e-02	 time: 44s
#
# Time to train: 446.212s
# Best learning rate: 0.012559432157547906
# best_lr: 0.012559432157547906

# %%
params = {'batch_size': 16, 'loss': F.smooth_l1_loss, 'weight_decay': 1e-5, 'epochs': 50, 'lr': best_lr_ResNet, 'batch_growth': False, 'l1_reg': 0}
max_batch_size = 256
best_model, best_val_loss, final_model, train_losses, val_losses = utils.train_model(ResNet, params, max_batch_size, print_mode=True)
# Out:
# Test; 	Test loss: 6.4932294 	 time: 3s
#
# Initial: Test loss: 6.4932294
#
# Test; 	Test loss: 2.6414050 	 time: 3s
# Epoch:1 	Train loss: 2.7124999 	Val loss: 2.6414050 	batch size: 16	 LR: 1.25e-02	 time: 45s
# Test; 	Test loss: 2.1797561 	 time: 3s
# Epoch:2 	Train loss: 2.1075008 	Val loss: 2.1797561 	batch size: 16	 LR: 1.25e-02	 time: 45s
# Test; 	Test loss: 2.1202708 	 time: 3s
# Epoch:3 	Train loss: 1.9687498 	Val loss: 2.1202708 	batch size: 16	 LR: 1.24e-02	 time: 45s
# Test; 	Test loss: 1.8253560 	 time: 3s
# Epoch:4 	Train loss: 1.8967010 	Val loss: 1.8253560 	batch size: 16	 LR: 1.24e-02	 time: 45s
# Test; 	Test loss: 1.9258612 	 time: 3s
# Epoch:5 	Train loss: 1.8544336 	Val loss: 1.9258612 	batch size: 16	 LR: 1.23e-02	 time: 46s
# Test; 	Test loss: 1.8132954 	 time: 3s
# Epoch:6 	Train loss: 1.8133446 	Val loss: 1.8132954 	batch size: 16	 LR: 1.21e-02	 time: 45s
# Test; 	Test loss: 1.8590010 	 time: 3s
# Epoch:7 	Train loss: 1.7965045 	Val loss: 1.8590010 	batch size: 16	 LR: 1.20e-02	 time: 45s
# Test; 	Test loss: 1.8874065 	 time: 3s
# Epoch:8 	Train loss: 1.7604892 	Val loss: 1.8874065 	batch size: 16	 LR: 1.18e-02	 time: 46s
# Test; 	Test loss: 1.7427552 	 time: 3s
# Epoch:9 	Train loss: 1.7411411 	Val loss: 1.7427552 	batch size: 16	 LR: 1.16e-02	 time: 46s
# Test; 	Test loss: 1.7942742 	 time: 3s
# Epoch:10 	Train loss: 1.7213683 	Val loss: 1.7942742 	batch size: 16	 LR: 1.14e-02	 time: 46s
# Test; 	Test loss: 1.8469122 	 time: 3s
# Epoch:11 	Train loss: 1.6958385 	Val loss: 1.8469122 	batch size: 16	 LR: 1.11e-02	 time: 46s
# Test; 	Test loss: 1.7033291 	 time: 3s
# Epoch:12 	Train loss: 1.6910291 	Val loss: 1.7033291 	batch size: 16	 LR: 1.09e-02	 time: 46s
# Test; 	Test loss: 1.8312199 	 time: 3s
# Epoch:13 	Train loss: 1.6618178 	Val loss: 1.8312199 	batch size: 16	 LR: 1.06e-02	 time: 46s
# Test; 	Test loss: 1.8612941 	 time: 3s
# Epoch:14 	Train loss: 1.6444783 	Val loss: 1.8612941 	batch size: 16	 LR: 1.03e-02	 time: 46s
# Test; 	Test loss: 1.7463683 	 time: 3s
# Epoch:15 	Train loss: 1.6368270 	Val loss: 1.7463683 	batch size: 16	 LR: 9.97e-03	 time: 46s
# Test; 	Test loss: 1.7160767 	 time: 3s
# Epoch:16 	Train loss: 1.6175170 	Val loss: 1.7160767 	batch size: 16	 LR: 9.64e-03	 time: 45s
# Test; 	Test loss: 1.7443599 	 time: 3s
# Epoch:17 	Train loss: 1.6064365 	Val loss: 1.7443599 	batch size: 16	 LR: 9.30e-03	 time: 46s
# Test; 	Test loss: 1.6629818 	 time: 3s
# Epoch:18 	Train loss: 1.5966149 	Val loss: 1.6629818 	batch size: 16	 LR: 8.95e-03	 time: 45s
# Test; 	Test loss: 1.6875744 	 time: 3s
# Epoch:19 	Train loss: 1.5832281 	Val loss: 1.6875744 	batch size: 16	 LR: 8.59e-03	 time: 45s
# Test; 	Test loss: 1.6447946 	 time: 3s
# Epoch:20 	Train loss: 1.5708921 	Val loss: 1.6447946 	batch size: 16	 LR: 8.22e-03	 time: 45s
# Test; 	Test loss: 1.7169533 	 time: 3s
# Epoch:21 	Train loss: 1.5480256 	Val loss: 1.7169533 	batch size: 16	 LR: 7.84e-03	 time: 45s
# Test; 	Test loss: 1.8598884 	 time: 3s
# Epoch:22 	Train loss: 1.5412474 	Val loss: 1.8598884 	batch size: 16	 LR: 7.46e-03	 time: 46s
# Test; 	Test loss: 1.6218920 	 time: 3s
# Epoch:23 	Train loss: 1.5229352 	Val loss: 1.6218920 	batch size: 16	 LR: 7.07e-03	 time: 45s
# Test; 	Test loss: 1.6261559 	 time: 3s
# Epoch:24 	Train loss: 1.5060408 	Val loss: 1.6261559 	batch size: 16	 LR: 6.67e-03	 time: 46s
# Test; 	Test loss: 1.7543281 	 time: 3s
# Epoch:25 	Train loss: 1.4909865 	Val loss: 1.7543281 	batch size: 16	 LR: 6.28e-03	 time: 45s
# Test; 	Test loss: 1.6638950 	 time: 3s
# Epoch:26 	Train loss: 1.4783526 	Val loss: 1.6638950 	batch size: 16	 LR: 5.89e-03	 time: 46s
# Test; 	Test loss: 1.6105976 	 time: 3s
# Epoch:27 	Train loss: 1.4580423 	Val loss: 1.6105976 	batch size: 16	 LR: 5.49e-03	 time: 45s
# Test; 	Test loss: 1.6930589 	 time: 3s
# Epoch:28 	Train loss: 1.4471269 	Val loss: 1.6930589 	batch size: 16	 LR: 5.10e-03	 time: 46s
# Test; 	Test loss: 1.6377191 	 time: 3s
# Epoch:29 	Train loss: 1.4326455 	Val loss: 1.6377191 	batch size: 16	 LR: 4.72e-03	 time: 45s
# Test; 	Test loss: 1.6443973 	 time: 3s
# Epoch:30 	Train loss: 1.4139151 	Val loss: 1.6443973 	batch size: 16	 LR: 4.34e-03	 time: 45s
# Test; 	Test loss: 1.5746133 	 time: 3s
# Epoch:31 	Train loss: 1.3997521 	Val loss: 1.5746133 	batch size: 16	 LR: 3.97e-03	 time: 45s
# Test; 	Test loss: 1.5875089 	 time: 3s
# Epoch:32 	Train loss: 1.3834569 	Val loss: 1.5875089 	batch size: 16	 LR: 3.61e-03	 time: 46s
# Test; 	Test loss: 1.5955788 	 time: 3s
# Epoch:33 	Train loss: 1.3685457 	Val loss: 1.5955788 	batch size: 16	 LR: 3.25e-03	 time: 47s
# Test; 	Test loss: 1.5914771 	 time: 3s
# Epoch:34 	Train loss: 1.3484422 	Val loss: 1.5914771 	batch size: 16	 LR: 2.91e-03	 time: 46s
# Test; 	Test loss: 1.5815825 	 time: 3s
# Epoch:35 	Train loss: 1.3307716 	Val loss: 1.5815825 	batch size: 16	 LR: 2.59e-03	 time: 46s
# Test; 	Test loss: 1.5752471 	 time: 3s
# Epoch:36 	Train loss: 1.3227527 	Val loss: 1.5752471 	batch size: 16	 LR: 2.28e-03	 time: 47s
# Test; 	Test loss: 1.5694510 	 time: 3s
# Epoch:37 	Train loss: 1.3011296 	Val loss: 1.5694510 	batch size: 16	 LR: 1.98e-03	 time: 47s
# Test; 	Test loss: 1.5652597 	 time: 3s
# Epoch:38 	Train loss: 1.2859234 	Val loss: 1.5652597 	batch size: 16	 LR: 1.70e-03	 time: 46s
# Test; 	Test loss: 1.5787694 	 time: 3s
# Epoch:39 	Train loss: 1.2742635 	Val loss: 1.5787694 	batch size: 16	 LR: 1.44e-03	 time: 45s
# Test; 	Test loss: 1.5767870 	 time: 3s
# Epoch:40 	Train loss: 1.2583138 	Val loss: 1.5767870 	batch size: 16	 LR: 1.20e-03	 time: 45s
# Test; 	Test loss: 1.5725021 	 time: 3s
# Epoch:41 	Train loss: 1.2497132 	Val loss: 1.5725021 	batch size: 16	 LR: 9.78e-04	 time: 45s
# Test; 	Test loss: 1.5828711 	 time: 3s
# Epoch:42 	Train loss: 1.2401917 	Val loss: 1.5828711 	batch size: 16	 LR: 7.77e-04	 time: 45s
# Test; 	Test loss: 1.5698071 	 time: 3s
# Epoch:43 	Train loss: 1.2285942 	Val loss: 1.5698071 	batch size: 16	 LR: 5.98e-04	 time: 45s
# Test; 	Test loss: 1.5707242 	 time: 3s
# Epoch:44 	Train loss: 1.2174953 	Val loss: 1.5707242 	batch size: 16	 LR: 4.41e-04	 time: 45s
# Test; 	Test loss: 1.5688787 	 time: 3s
# Epoch:45 	Train loss: 1.2152479 	Val loss: 1.5688787 	batch size: 16	 LR: 3.07e-04	 time: 45s
# Test; 	Test loss: 1.5749379 	 time: 3s
# Epoch:46 	Train loss: 1.2036523 	Val loss: 1.5749379 	batch size: 16	 LR: 1.97e-04	 time: 45s
# Test; 	Test loss: 1.5712250 	 time: 3s
# Epoch:47 	Train loss: 1.1982672 	Val loss: 1.5712250 	batch size: 16	 LR: 1.11e-04	 time: 45s
# Test; 	Test loss: 1.5699195 	 time: 3s
# Epoch:48 	Train loss: 1.1942228 	Val loss: 1.5699195 	batch size: 16	 LR: 4.95e-05	 time: 45s
# Test; 	Test loss: 1.5745083 	 time: 3s
# Epoch:49 	Train loss: 1.1956319 	Val loss: 1.5745083 	batch size: 16	 LR: 1.24e-05	 time: 45s
# Test; 	Test loss: 1.5735716 	 time: 3s
# Epoch:50 	Train loss: 1.1911442 	Val loss: 1.5735716 	batch size: 16	 LR: 0.00e+00	 time: 45s
# Test; 	Test loss: 1.5735716 	 time: 3s
#
# Time to train: 2282.972s	 final train loss:1.1911442	 final val loss:1.5735716

# %%
torch.save(best_model.state_dict(), "ResNet1.dict")

# %%
params = {'batch_size': 16, 'loss': F.smooth_l1_loss, 'weight_decay': 1e-3, 'epochs': 50, 'lr': best_lr_ResNet, 'batch_growth': False, 'l1_reg': 0}
max_batch_size = 256
best_model, best_val_loss, final_model, train_losses, val_losses = utils.train_model(ResNet, params, max_batch_size, print_mode=True)
# Out:
# Test; 	Test loss: 6.4936434 	 time: 3s
#
# Initial: Test loss: 6.4936434
#
# Test; 	Test loss: 2.5272566 	 time: 4s
# Epoch:1 	Train loss: 2.8823194 	Val loss: 2.5272566 	batch size: 16	 LR: 1.99e-03	 time: 60s
# Test; 	Test loss: 2.4921245 	 time: 3s
# Epoch:2 	Train loss: 2.0940895 	Val loss: 2.4921245 	batch size: 16	 LR: 1.98e-03	 time: 73s
# Test; 	Test loss: 2.1517120 	 time: 3s
# Epoch:3 	Train loss: 1.9750865 	Val loss: 2.1517120 	batch size: 16	 LR: 1.97e-03	 time: 67s
# Test; 	Test loss: 2.2061101 	 time: 3s
# Epoch:4 	Train loss: 1.9118599 	Val loss: 2.2061101 	batch size: 16	 LR: 1.96e-03	 time: 65s
# Test; 	Test loss: 2.0522352 	 time: 3s
# Epoch:5 	Train loss: 1.8905068 	Val loss: 2.0522352 	batch size: 16	 LR: 1.94e-03	 time: 53s
# Test; 	Test loss: 2.0376749 	 time: 3s
# Epoch:6 	Train loss: 1.8419415 	Val loss: 2.0376749 	batch size: 16	 LR: 1.92e-03	 time: 50s
# Test; 	Test loss: 2.2504426 	 time: 3s
# Epoch:7 	Train loss: 1.8141059 	Val loss: 2.2504426 	batch size: 16	 LR: 1.90e-03	 time: 52s
# Test; 	Test loss: 1.9435361 	 time: 4s
# Epoch:8 	Train loss: 1.7846790 	Val loss: 1.9435361 	batch size: 16	 LR: 1.87e-03	 time: 52s
# Test; 	Test loss: 1.6965564 	 time: 3s
# Epoch:9 	Train loss: 1.7662295 	Val loss: 1.6965564 	batch size: 16	 LR: 1.84e-03	 time: 62s
# Test; 	Test loss: 1.7975622 	 time: 4s
# Epoch:10 	Train loss: 1.7488915 	Val loss: 1.7975622 	batch size: 16	 LR: 1.80e-03	 time: 71s
# Test; 	Test loss: 1.6839319 	 time: 3s
# Epoch:11 	Train loss: 1.7279473 	Val loss: 1.6839319 	batch size: 16	 LR: 1.76e-03	 time: 65s
# Test; 	Test loss: 1.6950008 	 time: 3s
# Epoch:12 	Train loss: 1.7060795 	Val loss: 1.6950008 	batch size: 16	 LR: 1.72e-03	 time: 62s
# Test; 	Test loss: 1.8473582 	 time: 4s
# Epoch:13 	Train loss: 1.6888450 	Val loss: 1.8473582 	batch size: 16	 LR: 1.68e-03	 time: 68s
# Test; 	Test loss: 1.7007924 	 time: 3s
# Epoch:14 	Train loss: 1.6806836 	Val loss: 1.7007924 	batch size: 16	 LR: 1.63e-03	 time: 66s
# Test; 	Test loss: 1.9292532 	 time: 3s
# Epoch:15 	Train loss: 1.6616665 	Val loss: 1.9292532 	batch size: 16	 LR: 1.58e-03	 time: 68s
# Test; 	Test loss: 1.8051146 	 time: 3s
# Epoch:16 	Train loss: 1.6456362 	Val loss: 1.8051146 	batch size: 16	 LR: 1.53e-03	 time: 56s
# Test; 	Test loss: 1.5953463 	 time: 3s
# Epoch:17 	Train loss: 1.6398170 	Val loss: 1.5953463 	batch size: 16	 LR: 1.47e-03	 time: 61s
# Test; 	Test loss: 1.6755158 	 time: 3s
# Epoch:18 	Train loss: 1.6307471 	Val loss: 1.6755158 	batch size: 16	 LR: 1.42e-03	 time: 60s
# Test; 	Test loss: 1.6467051 	 time: 3s
# Epoch:19 	Train loss: 1.6123699 	Val loss: 1.6467051 	batch size: 16	 LR: 1.36e-03	 time: 58s
# Test; 	Test loss: 1.6008047 	 time: 3s
# Epoch:20 	Train loss: 1.5962888 	Val loss: 1.6008047 	batch size: 16	 LR: 1.30e-03	 time: 58s
# Test; 	Test loss: 1.7684931 	 time: 3s
# Epoch:21 	Train loss: 1.5875153 	Val loss: 1.7684931 	batch size: 16	 LR: 1.24e-03	 time: 60s
# Test; 	Test loss: 1.5995826 	 time: 3s
# Epoch:22 	Train loss: 1.5691511 	Val loss: 1.5995826 	batch size: 16	 LR: 1.18e-03	 time: 61s
# Test; 	Test loss: 1.7576093 	 time: 3s
# Epoch:23 	Train loss: 1.5652210 	Val loss: 1.7576093 	batch size: 16	 LR: 1.12e-03	 time: 59s
# Test; 	Test loss: 1.5175688 	 time: 3s
# Epoch:24 	Train loss: 1.5434638 	Val loss: 1.5175688 	batch size: 16	 LR: 1.06e-03	 time: 58s
# Test; 	Test loss: 1.5461865 	 time: 3s
# Epoch:25 	Train loss: 1.5320227 	Val loss: 1.5461865 	batch size: 16	 LR: 9.95e-04	 time: 59s
# Test; 	Test loss: 1.6060183 	 time: 3s
# Epoch:26 	Train loss: 1.5298260 	Val loss: 1.6060183 	batch size: 16	 LR: 9.33e-04	 time: 59s
# Test; 	Test loss: 1.5400764 	 time: 3s
# Epoch:27 	Train loss: 1.5223830 	Val loss: 1.5400764 	batch size: 16	 LR: 8.71e-04	 time: 59s
# Test; 	Test loss: 1.5558320 	 time: 3s
# Epoch:28 	Train loss: 1.4976289 	Val loss: 1.5558320 	batch size: 16	 LR: 8.09e-04	 time: 55s
# Test; 	Test loss: 1.5191530 	 time: 3s
# Epoch:29 	Train loss: 1.4859958 	Val loss: 1.5191530 	batch size: 16	 LR: 7.48e-04	 time: 59s
# Test; 	Test loss: 1.5572912 	 time: 3s
# Epoch:30 	Train loss: 1.4721725 	Val loss: 1.5572912 	batch size: 16	 LR: 6.88e-04	 time: 60s
# Test; 	Test loss: 1.5648401 	 time: 3s
# Epoch:31 	Train loss: 1.4581321 	Val loss: 1.5648401 	batch size: 16	 LR: 6.29e-04	 time: 57s
# Test; 	Test loss: 1.5227298 	 time: 3s
# Epoch:32 	Train loss: 1.4433819 	Val loss: 1.5227298 	batch size: 16	 LR: 5.72e-04	 time: 54s
# Test; 	Test loss: 1.5073275 	 time: 3s
# Epoch:33 	Train loss: 1.4316014 	Val loss: 1.5073275 	batch size: 16	 LR: 5.16e-04	 time: 61s
# Test; 	Test loss: 1.4851911 	 time: 3s
# Epoch:34 	Train loss: 1.4228276 	Val loss: 1.4851911 	batch size: 16	 LR: 4.62e-04	 time: 61s
# Test; 	Test loss: 1.5227170 	 time: 3s
# Epoch:35 	Train loss: 1.4103365 	Val loss: 1.5227170 	batch size: 16	 LR: 4.10e-04	 time: 56s
# Test; 	Test loss: 1.5624694 	 time: 3s
# Epoch:36 	Train loss: 1.3956605 	Val loss: 1.5624694 	batch size: 16	 LR: 3.61e-04	 time: 55s
# Test; 	Test loss: 1.4882091 	 time: 3s
# Epoch:37 	Train loss: 1.3871310 	Val loss: 1.4882091 	batch size: 16	 LR: 3.14e-04	 time: 56s
# Test; 	Test loss: 1.4857100 	 time: 3s
# Epoch:38 	Train loss: 1.3710586 	Val loss: 1.4857100 	batch size: 16	 LR: 2.70e-04	 time: 61s
# Test; 	Test loss: 1.4902245 	 time: 3s
# Epoch:39 	Train loss: 1.3610391 	Val loss: 1.4902245 	batch size: 16	 LR: 2.28e-04	 time: 57s
# Test; 	Test loss: 1.4862919 	 time: 3s
# Epoch:40 	Train loss: 1.3465090 	Val loss: 1.4862919 	batch size: 16	 LR: 1.90e-04	 time: 57s
# Test; 	Test loss: 1.4749404 	 time: 3s
# Epoch:41 	Train loss: 1.3387942 	Val loss: 1.4749404 	batch size: 16	 LR: 1.55e-04	 time: 55s
# Test; 	Test loss: 1.4961746 	 time: 3s
# Epoch:42 	Train loss: 1.3289402 	Val loss: 1.4961746 	batch size: 16	 LR: 1.23e-04	 time: 62s
# Test; 	Test loss: 1.4906929 	 time: 3s
# Epoch:43 	Train loss: 1.3223836 	Val loss: 1.4906929 	batch size: 16	 LR: 9.47e-05	 time: 58s
# Test; 	Test loss: 1.4930640 	 time: 3s
# Epoch:44 	Train loss: 1.3132280 	Val loss: 1.4930640 	batch size: 16	 LR: 6.99e-05	 time: 59s
# Test; 	Test loss: 1.4721112 	 time: 3s
# Epoch:45 	Train loss: 1.3065395 	Val loss: 1.4721112 	batch size: 16	 LR: 4.87e-05	 time: 58s
# Test; 	Test loss: 1.4857796 	 time: 4s
# Epoch:46 	Train loss: 1.3050830 	Val loss: 1.4857796 	batch size: 16	 LR: 3.13e-05	 time: 61s
# Test; 	Test loss: 1.4733456 	 time: 3s
# Epoch:47 	Train loss: 1.2931141 	Val loss: 1.4733456 	batch size: 16	 LR: 1.76e-05	 time: 58s
# Test; 	Test loss: 1.4765087 	 time: 3s
# Epoch:48 	Train loss: 1.2905722 	Val loss: 1.4765087 	batch size: 16	 LR: 7.85e-06	 time: 58s
# Test; 	Test loss: 1.4744092 	 time: 3s
# Epoch:49 	Train loss: 1.2910319 	Val loss: 1.4744092 	batch size: 16	 LR: 1.96e-06	 time: 56s
# Test; 	Test loss: 1.4764346 	 time: 4s
# Epoch:50 	Train loss: 1.2884626 	Val loss: 1.4764346 	batch size: 16	 LR: 0.00e+00	 time: 64s
# Test; 	Test loss: 1.4764346 	 time: 3s
#
# Time to train: 2986.051s	 final train loss:1.2884626	 final val loss:1.4764346

# %%
params = {'batch_size': 32, 'loss': 'SmoothL1', 'weight_decay': 1e-5, 'hidden_size': 100, 'dropout_rate': 0, 'epochs': 10, 'lr': 1e-5, 'batch_growth': False, 'l1_reg': 0}
model = ResNet(params)
model.load_state_dict(torch.load("ResNet1.dict", weights_only=True))
model = model.cuda()
utils.dataset.evaluate_model(model, 32)
# Out:
# Train metrics:
# 	MSE: tensor(5.4354, device='cuda:0')
#
# 	RMSE: tensor(2.3314, device='cuda:0')
#
# 	MAE: tensor(1.6670, device='cuda:0')
#
# Validation metrics:
# 	MSE: tensor(6.7290, device='cuda:0')
#
# 	RMSE: tensor(2.5940, device='cuda:0')
#
# 	MAE: tensor(1.9078, device='cuda:0')
#
# Test metrics:
# 	MSE: tensor(6.0708, device='cuda:0')
#
# 	RMSE: tensor(2.4639, device='cuda:0')
#
# 	MAE: tensor(1.8133, device='cuda:0')

# %%
#This function gives the ldos from a model
import matplotlib.pyplot as plt

model.load_state_dict(torch.load("ResNet1.dict", weights_only=True))
model = model.cuda()
#model.eval()

preds = model(utils.dataset.X_test[:6])

print(torch.min(utils.dataset.X_test[0]), torch.max(utils.dataset.X_test[0]))
print(utils.dataset.X_test[0].shape)

plt.figure(figsize=(12, 7))  
import matplotlib.pyplot as plt
for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.imshow(utils.dataset.X_test[i].cpu().T)
    plt.title("P: {:.1f}   T: {}".format(float(preds[i].cpu()), float(utils.dataset.Y_test[i].cpu())))
plt.show()
# Out:
# tensor(0., device='cuda:0', dtype=torch.float16) tensor(1., device='cuda:0', dtype=torch.float16)
# torch.Size([64, 64])

# %%
import struct

def load_sample(path):
    with open(path, 'rb') as f:
        data = f.read()
        f.close()
    
    topo = []
    for i in range(int(len((data))/4)):
        topo_numvalue = struct.unpack('<i', data[4*i:4*i+4])[0]
        topo.append(topo_numvalue)
    
    topo = np.array(topo)
    res = int(np.sqrt(topo.shape[0]))
    topo = topo.reshape(res, res)
    #topo_min = np.min(topo, axis = 1)[:, None]
    #topo_max = np.max(topo, axis = 1)[:, None]
    #topo = (topo - topo_min) / (topo_max - topo_min)
    topo = (topo - np.min(topo)) / (np.max(topo) - np.min(topo))
    return topo

folder = "20230818_Lance_WSe2-CVD[10K]/"
#file = "20230818_Lance_WSe2-CVD_163TopoBwd.int"
file = "20230818_Lance_WSe2-CVD_164TopoBwd.int"

path = folder + file
topo = load_sample(path)

plt.figure(figsize=(12, 7)) 
plt.imshow(topo)

plt.title("Z profile")
plt.colorbar()
plt.show()

res = 64

off_x = 300
off_y = 300

test_sample = topo[off_x:off_x+res, off_y:off_y+res]

plt.figure(figsize=(12, 7)) 
plt.imshow(test_sample)
#plt.colorbar()
plt.show()

# %%
model.eval()

test_sample_t = torch.from_numpy(test_sample.reshape((1, res, res))).to(dtype = torch.float16).cuda()
test_sample_t = (test_sample_t - torch.min(test_sample_t)) / (torch.max(test_sample_t) - torch.min(test_sample_t))
print(torch.max(test_sample_t), torch.min(test_sample_t))

print(model(test_sample_t))
# Out:
# tensor(1., device='cuda:0', dtype=torch.float16) tensor(0., device='cuda:0', dtype=torch.float16)
# tensor([[27.8857]], device='cuda:0', grad_fn=<AddmmBackward0>)
